# %% [markdown]
# ## 作業 1

# %% [markdown]
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# [Air quality in northern Taiwan](https://www.kaggle.com/nelsonchu/air-quality-in-northern-taiwan)
#
# * 你選的這組資料為何重要
#
#     空氣品質是近年來越來越被關注的議題，其變化對人民的生活和政府的決策都會帶來影響
#
#
# * 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#     行政院環境保護署提供
#
#
# * 蒐集而來的資料型態為何
#
#     包含時間、地點及各項空氣相關數據的 CSV 檔案
#
#
# * 這組資料想解決的問題如何評估
#
#     可將空汙（像是 CO、O<sub>3</sub>、PM2.5 等）和其他數據（像是 RAINFALL、RH、WIND_SPEED 等）分析其相關性

# %% [markdown]
# ## 作業 2

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# * 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#     預測客群出沒的時間地點，來減少客人等待的時間及司機無載客的時間，達到高載客率、提升業績的效果。
#
#     例如：假設下大雨時，上班時間的住宅區需求量會明顯上升，那麼司機在雨天的上班時間時若能聚集到住宅區，就能有效達到高載客率。
#
#
# * 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#     根據過往的叫車紀錄及載客紀錄，並加入天氣、節日、突發事件（像是捷運停駛）等因素
#
#
# * 蒐集而來的資料型態為何
#
#     時間、地點、同時叫車人數、平均等候時間、天氣狀態等數據
#
#
# * 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#     分析時間（上班時間 08:00~09:00）、地點（住宅區）的載客量和天氣是否有相關性

# %% [markdown]
# ## 作業 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    return sum((y - yp) ** 2) / len(y)

# %%
def mean_absolute_error(y, yp):
    return sum(abs(y - yp)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 225.152
# The Mean absolute error is 12.137
